# %% [markdown]
# # advance dataframes

# %%
import pandas as pd
import numpy as np

np.random.seed(123)

# %% [markdown]
# # Exercises I

# %% [markdown]
# # Create a function named get_db_url. It should accept a username, hostname, password, and database name and return a url connection string formatted like in the example at the start of this lesson.

# %%
from env import host, user, password

url = f'mysql+pymysql://{user}:{password}@{host}/employees'

# %% [markdown]
# # Use your function to obtain a connection to the employees database.

# %%
def get_db_url(user,password,host,database):
    return f'mysql+pymysql://{user}:{password}@{host}/employees'

# %% [markdown]
# # Once you have successfully run a query:
#
# a. Intentionally make a typo in the database url. What kind of error message do you see?
#
# b. Intentionally make an error in your SQL query. What does the error message look like?

# %%
get_sql_url
# Out:
# <function __main__.get_sql_url(user, password, host, database)>

# %% [markdown]
# # Read the employees and titles tables into two separate DataFrames.

# %%
pd.read_sql('SELECT * FROM employees LIMIT 5 OFFSET 50', url)
# Out:
#    emp_no  birth_date first_name  last_name gender   hire_date
# 0   10051  1953-07-28   Hidefumi      Caine      M  1992-10-15
# 1   10052  1961-02-26     Heping     Nitsch      M  1988-05-21
# 2   10053  1954-09-13     Sanjiv   Zschoche      F  1986-02-04
# 3   10054  1957-04-04     Mayumi  Schueller      M  1995-03-13
# 4   10055  1956-06-06     Georgy     Dredge      M  1992-04-27

# %%
pd.read_sql('SELECT * FROM employees', url)
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12
# ...        ...         ...        ...       ...    ...         ...
# 300019  499995  1958-09-24     Dekang  Lichtner      F  1993-01-12
# 300020  499996  1953-03-07       Zito      Baaz      M  1990-09-27
# 300021  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 300022  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 300023  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
# [300024 rows x 6 columns]

# %%
pd.read_sql('SELECT * FROM titles LIMIT 5 OFFSET 50', url)
# Out:
#    emp_no            title   from_date     to_date
# 0   10036     Senior Staff  1992-04-28  9999-01-01
# 1   10037         Engineer  1990-12-05  1995-12-05
# 2   10037  Senior Engineer  1995-12-05  9999-01-01
# 3   10038     Senior Staff  1996-09-20  9999-01-01
# 4   10038            Staff  1989-09-20  1996-09-20

# %%
pd.read_sql('SELECT * FROM titles', url)
# Out:
#         emp_no            title   from_date     to_date
# 0        10001  Senior Engineer  1986-06-26  9999-01-01
# 1        10002            Staff  1996-08-03  9999-01-01
# 2        10003  Senior Engineer  1995-12-03  9999-01-01
# 3        10004         Engineer  1986-12-01  1995-12-01
# 4        10004  Senior Engineer  1995-12-01  9999-01-01
# ...        ...              ...         ...         ...
# 443303  499997         Engineer  1987-08-30  1992-08-29
# 443304  499997  Senior Engineer  1992-08-29  9999-01-01
# 443305  499998     Senior Staff  1998-12-27  9999-01-01
# 443306  499998            Staff  1993-12-27  1998-12-27
# 443307  499999         Engineer  1997-11-30  9999-01-01
#
# [443308 rows x 4 columns]

# %% [markdown]
# # Display the summary statistics for each DataFrame.

# %%
pd.read_sql('SELECT * FROM titles', url).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443308 entries, 0 to 443307
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   emp_no     443308 non-null  int64
#  1   title      443308 non-null  object
#  2   from_date  443308 non-null  object
#  3   to_date    443308 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 13.5+ MB

# %%
pd.read_sql('SELECT * FROM titles', url).describe()
# Out:
#               emp_no
# count  443308.000000
# mean   253075.034430
# std    161853.292613
# min     10001.000000
# 25%     84855.750000
# 50%    249847.500000
# 75%    424891.250000
# max    499999.000000

# %%
pd.read_sql('SELECT * FROM employees', url).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300024 entries, 0 to 300023
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   emp_no      300024 non-null  int64
#  1   birth_date  300024 non-null  object
#  2   first_name  300024 non-null  object
#  3   last_name   300024 non-null  object
#  4   gender      300024 non-null  object
#  5   hire_date   300024 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 13.7+ MB

# %%
pd.read_sql('SELECT * FROM employees', url).describe()
# Out:
#               emp_no
# count  300024.000000
# mean   253321.763392
# std    161828.235540
# min     10001.000000
# 25%     85006.750000
# 50%    249987.500000
# 75%    424993.250000
# max    499999.000000

# %% [markdown]
# # How many unique titles are in the titles DataFrame?

# %%
pd.read_sql('SELECT title FROM titles', url).value_counts()
# Out:
# title
# Engineer              115003
# Staff                 107391
# Senior Engineer        97750
# Senior Staff           92853
# Technique Leader       15159
# Assistant Engineer     15128
# Manager                   24
# dtype: int64

# %%
pd.read_sql('SELECT title FROM titles', url).describe()
# Out:
#            title
# count     443308
# unique         7
# top     Engineer
# freq      115003

# %% [markdown]
# # What is the oldest date in the to_date column?

# %%
pd.read_sql('SELECT to_date FROM titles', url).min()
# Out:
# to_date    1985-03-01
# dtype: object

# %% [markdown]
# # What is the most recent date in the to_date column?

# %%
pd.read_sql('SELECT to_date FROM titles', url).max()
# Out:
# to_date    9999-01-01
# dtype: object

# %% [markdown]
# # Exercises II

# %%
#1 Copy the users and roles DataFrames from the examples above.
users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})
users
# Out:
#    id   name  role_id
# 0   1    bob      1.0
# 1   2    joe      2.0
# 2   3  sally      3.0
# 3   4   adam      3.0
# 4   5   jane      NaN
# 5   6   mike      NaN

# %%
roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %%
users.merge(roles, left_on='role_id', right_on='id', how='outer', indicator=True)
# Out:
#    id_x name_x  role_id  id_y     name_y      _merge
# 0   1.0    bob      1.0   1.0      admin        both
# 1   2.0    joe      2.0   2.0     author        both
# 2   3.0  sally      3.0   3.0   reviewer        both
# 3   4.0   adam      3.0   3.0   reviewer        both
# 4   5.0   jane      NaN   NaN        NaN   left_only
# 5   6.0   mike      NaN   NaN        NaN   left_only
# 6   NaN    NaN      NaN   4.0  commenter  right_only

# %%
(users.merge(roles, 
            left_on='role_id', 
            right_on='id', 
            how='outer')
    .drop(columns='role_id')
    .rename(columns={'id_x': 'id', 
                     'name_x': 'employee',
                     'id_y': 'role_id',
                     'name_y': 'role'}
            )
)
# Out:
#     id employee  role_id       role
# 0  1.0      bob      1.0      admin
# 1  2.0      joe      2.0     author
# 2  3.0    sally      3.0   reviewer
# 3  4.0     adam      3.0   reviewer
# 4  5.0     jane      NaN        NaN
# 5  6.0     mike      NaN        NaN
# 6  NaN      NaN      4.0  commenter

# %%
#2 What is the result of using a right join on the DataFrames?
right_join_df= pd.merge(users, roles, on='id', how='right')

right_join_df
# Out:
#    id name_x  role_id     name_y
# 0   1    bob      1.0      admin
# 1   2    joe      2.0     author
# 2   3  sally      3.0   reviewer
# 3   4   adam      3.0  commenter

# %%
join_right = users.merge(roles, left_on='role_id', right_on='id', how='right', indicator=True)
join_right
# Out:
#    id_x name_x  role_id  id_y     name_y      _merge
# 0   1.0    bob      1.0     1      admin        both
# 1   2.0    joe      2.0     2     author        both
# 2   3.0  sally      3.0     3   reviewer        both
# 3   4.0   adam      3.0     3   reviewer        both
# 4   NaN    NaN      NaN     4  commenter  right_only

# %%
#3 What is the result of using an outer join on the DataFrames?

outer_join_df=pd.merge(users, roles, on='id', how='outer')

outer_join_df
# Out:
#    id name_x  role_id     name_y
# 0   1    bob      1.0      admin
# 1   2    joe      2.0     author
# 2   3  sally      3.0   reviewer
# 3   4   adam      3.0  commenter
# 4   5   jane      NaN        NaN
# 5   6   mike      NaN        NaN

# %%
roles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      4 non-null      int64
#  1   name    4 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 192.0+ bytes

# %%
#4 What happens if you drop the foreign keys from the DataFrames and try to merge them?
df_index = pd.merge(roles, users, right_index=True, left_index=True)

df_index
# Out:
#    id_x     name_x  id_y name_y  role_id
# 0     1      admin     1    bob      1.0
# 1     2     author     2    joe      2.0
# 2     3   reviewer     3  sally      3.0
# 3     4  commenter     4   adam      3.0

# %%
#5 Load the mpg dataset from PyDataset.
from pydataset import data
from pydataset import data
mpg = data('mpg')
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
data('mpg', show_doc=True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %%
#6 Output and read the documentation for the mpg dataset.
mpg.info
# Out:
# <bound method DataFrame.info of     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ...

# %%
#7 How many rows and columns are in the dataset? 
mpg.shape
# Out:
# (234, 11)

# %%
#8 Check out your column names and perform any cleanup you may want on them.
mpg.columns
# could rename "class" as it is a python function
# fl. is fuel_type
# Out:
# Index(['manufacturer', 'model', 'displ', 'year', 'cyl', 'trans', 'drv', 'cty',
#        'hwy', 'fl', 'class'],
#       dtype='object')

# %%
mpg.trans.sample(10)
# Out:
# 92       auto(l4)
# 152    manual(m5)
# 166      auto(l4)
# 157      auto(l4)
# 134      auto(l4)
# 179      auto(l5)
# 109      auto(l4)
# 202      auto(l4)
# 203    manual(m5)
# 21       auto(l4)
# Name: trans, dtype: object

# %%
#9 Display the summary statistics for the dataset.
mpg.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
#10 How many different manufacturers are there?
mpg.manufacturer.unique()
# Out:
# array(['audi', 'chevrolet', 'dodge', 'ford', 'honda', 'hyundai', 'jeep',
#        'land rover', 'lincoln', 'mercury', 'nissan', 'pontiac', 'subaru',
#        'toyota', 'volkswagen'], dtype=object)

# %%
mpg.manufacturer.nunique()
# Out:
# 15

# %%
mpg.manufacturer.unique().size
# Out:
# 15

# %%
#11 How many different models are there?
mpg.model.value_counts().count()
# Out:
# 38

# %%
mpg.model.unique().size
# Out:
# 38

# %%
#12 Create a column named mileage_difference like you did in the DataFrames exercises; 
#this column should contain the difference between highway and city mileage for each car.
mpg['mileage_difference'] = mpg.hwy - mpg.cty
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  mileage_difference
# 1    compact                  11
# 2    compact                   8
# ...

# %%
#13 Create a column named average_mileage like you did in the DataFrames exercises; 
#this is the mean of the city and highway mileage.
mpg['average_mileage'] = (mpg.hwy + mpg.cty) / 2
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  mileage_difference  average_mileage
# 1    compact                  11             23.5
# ...

# %%
#14 Create a new column on the mpg dataset named is_automatic that holds boolean values denoting whether the car has an automatic transmission.
mpg['is_automatic'] = np.where(mpg.trans == ('manual(m5)', 'manual', 'automatic')
mpg # does not want to work
# mpg["is_automatic"] = np.where(mpg.trans.str.contains('auto'), True, False)
                               #this one should work
# Out:
#   File "<ipython-input-50-f8baf6f2b646>", line 3
#     mpg # does not want to work
#     ^
# SyntaxError: invalid syntax

# %%
mpg["is_automatic"] = np.where(mpg.trans.str.contains('auto'), True, False)
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  mileage_difference  average_mileage  is_automatic
# ...

# %%
#14 example
mpg['is_automatic'] = mpg.trans.str.contains("auto")
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  mileage_difference  average_mileage  is_automatic
# ...

# %%
mpg.trans.unique()
# Out:
# array(['auto(l5)', 'manual(m5)', 'manual(m6)', 'auto(av)', 'auto(s6)',
#        'auto(l4)', 'auto(l3)', 'auto(l6)', 'auto(s5)', 'auto(s4)'],
#       dtype=object)

# %%
#is_automatic = np.where( mpg.trans.str.startswith('auto') , 'Auto', 'Manual')

# %%
#15 Using the mpg dataset, find out which which manufacturer has the best miles per gallon on average?
# for each manufacturer, calculate the average of their mpg
#the 'for each' means that we need to change our level of observation/detail
#mpg rows == observations == specific car
#to change our rows into manufacturer, we will group by manufacturer
m_avg_mpg = mpg.groupby("manufacturer").average_mileage.mean()
m_avg_mpg
# Out:
# manufacturer
# audi          22.027778
# chevrolet     18.447368
# dodge         15.540541
# ford          16.680000
# honda         28.500000
# hyundai       22.750000
# jeep          15.562500
# land rover    14.000000
# lincoln       14.166667
# mercury       15.625000
# nissan        21.346154
# pontiac       21.700000
# subaru        22.428571
# toyota        21.720588
# volkswagen    25.074074
# Name: average_mileage, dtype: float64

# %%
m_avg_mpg.idxmax()
# Out:
# 'honda'

# %%
mpg.groupby('manufacturer').average_mileage.agg(['mean']).idxmax()[0]
# Out:
# 'honda'

# %%
#16 Do automatic or manual cars have better miles per gallon?
mpg.groupby("trans").average_mileage.mean()
# Out:
# trans
# auto(av)      23.900000
# auto(l3)      24.000000
# auto(l4)      18.951807
# auto(l5)      17.717949
# auto(l6)      16.833333
# auto(s4)      22.166667
# auto(s5)      21.333333
# auto(s6)      21.281250
# manual(m5)    22.775862
# manual(m6)    20.552632
# Name: average_mileage, dtype: float64

# %% [markdown]
# # Exercises III

# %%
#1 Use your get_db_url function to help you explore the data from the chipotle database.

# %%
from env import host, user, password

url = f'mysql+pymysql://{user}:{password}@{host}/chipotle'

# %% [markdown]
# def get_db_url(user,password,host,database):
#     return f'mysql+pymysql://{user}:{password}@{host}/{database}'
# url = get_db_url = get_db_url(user, password, host, 'chipotle')
# pd.read_sql('SELECT * FROM orders', url)

# %%
pd.read_sql('SELECT * FROM orders', url)
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# ...

# %%
pd.read_sql('SELECT * FROM orders', url).groupby('order_id').agg('item_price').sum()
# Out:
# order_id
# 1       $2.39 $3.39 $3.39 $2.39
# 2                        $16.98
# 3                  $10.98 $1.69
# 4                  $11.75 $9.25
# 5                   $9.25 $4.45
#                   ...
# 1830              $11.75 $11.25
# 1831          $9.25 $2.15 $1.50
# 1832                $8.75 $4.45
# 1833              $11.75 $11.75
# 1834         $11.25 $8.75 $8.75
# Name: item_price, Length: 1834, dtype: object

# %%
#2 What is the total price for each order?
pd.read_sql('SELECT * FROM orders', url).groupby('order_id').agg('item_price').sum()
# Out:
# order_id
# 1       $2.39 $3.39 $3.39 $2.39
# 2                        $16.98
# 3                  $10.98 $1.69
# 4                  $11.75 $9.25
# 5                   $9.25 $4.45
#                   ...
# 1830              $11.75 $11.25
# 1831          $9.25 $2.15 $1.50
# 1832                $8.75 $4.45
# 1833              $11.75 $11.75
# 1834         $11.25 $8.75 $8.75
# Name: item_price, Length: 1834, dtype: object

# %%
pd.read_sql('SELECT order_id, item_price FROM orders', url)
# Out:
#       order_id item_price
# 0            1     $2.39
# 1            1     $3.39
# 2            1     $3.39
# 3            1     $2.39
# 4            2    $16.98
# ...        ...        ...
# 4617      1833    $11.75
# 4618      1833    $11.75
# 4619      1834    $11.25
# 4620      1834     $8.75
# 4621      1834     $8.75
#
# [4622 rows x 2 columns]

# %%
#3 What are the most popular 3 items?
pd.read_sql('SELECT quantity, item_name FROM orders', url).groupby('item_name')

# %%
#4 Which item has produced the most revenue?
pd.read_sql('SELECT item_name, item_price FROM orders', url).groupby('item_name').sum()
# Out:
#                                                                               item_price
# item_name
# 6 Pack Soft Drink                      $6.49 $6.49 $6.49 $6.49 $6.49 $6.49 $6.49 $6.4...
# Barbacoa Bowl                          $11.75 $11.75 $9.25 $8.99 $9.25 $11.75 $9.25 $...
# Barbacoa Burrito                       $8.99 $9.25 $9.25 $11.75 $11.75 $9.25 $8.99 $1...
# Barbacoa Crispy Tacos                  $11.75 $9.25 $11.48 $11.75 $9.25 $9.25 $8.99 $...
# Barbacoa Salad Bowl                    $11.89 $11.89 $9.39 $9.39 $9.39 $11.89 $11.89 ...
# Barbacoa Soft Tacos                    $9.25 $9.25 $8.99 $9.25 $9.25 $11.75 $11.75 $9...
# Bottled Water                          $1.09 $1.09 $1.09 $1.50 $1.50 $1.50 $3.00 $1.5...
# Bowl                                                                       $22.20 $7.40
# Burrito                                             $7.40 $7.40 $7.40 $7.40 $7.40 $7.40
# ...

# %%
from env import host, user, password

url = f'mysql+pymysql://{user}:{password}@{host}/employees'

# %%
pd.read_sql('SELECT * FROM employees', url)
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12
# ...        ...         ...        ...       ...    ...         ...
# 300019  499995  1958-09-24     Dekang  Lichtner      F  1993-01-12
# 300020  499996  1953-03-07       Zito      Baaz      M  1990-09-27
# 300021  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 300022  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 300023  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
# [300024 rows x 6 columns]

# %%
#5 Join the employees and titles DataFrames together.

# %%
#6 For each title, find the hire date of the employee that was hired most recently with that title.
#may need to use groupby
# employees_titles.groupby(by = 'title').hire_date.max()

# %%
#7 Write the code necessary to create a cross tabulation of the number of titles by department.
#(Hint: this will involve a combination of SQL code to pull the necessary data and python/pandas code to perform the manipulations.)
query = '''
SELECT *
FROM employees
JOIN titles USING(emp_no)
JOIN dept_emp USING(emp_no)
JOIN departments USING(dept_no)
'''

pd.read_sql('SELECT * FROM employees', url, query)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-112-8181846260ae> in <module>
#       9 '''
#      10
# ---> 11 pd.read_sql('SELECT * FROM employees', url, query)
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     519         )
#     520     else:
# --> 521         return pandas_sql.read_query(
#     522             sql,
#     523             index_col=index_col,
#
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1320         else:
#    1321             data = result.fetchall()
# -> 1322             frame = _wrap_result(
#    1323                 data,
#    1324                 columns,
#
# ...

# %%
pd.Timestamp.now()
# Out:
# Timestamp('2021-07-21 11:18:42.728921')
