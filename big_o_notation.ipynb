# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
from scipy.special import gamma
from scipy.special import factorial

# %% [markdown]
# # 5 Make a new Jupyter notebook named big_o_notation.ipynb
# Title your chart "Big O Notation"
#
# Label your x axis "Elements"
#
# Label your y axis "Operations"
#
# Label your curves or make a legend for the curves
#
# Use LaTex notation where possible
#
# y=0n+1 and label the curve "O(1)"
#
# y=log(n) and label the curve "O(log n)"
#
# y=n and label the curve "O(n)"
#
# y=n∗log(n) and label it "O(n log n)"
#
# y=n2 and label it "O(n^2)"
#
# y=2n and label it "O(2^n)"
#
# y=n! and label it "O(n!)"
#
# y=nn and label it "O(n^n)"

# %%
plt.figure(figsize=(15, 5))


x= list(np.arange(0,5,.01))

plt.plot(x, [n + 1 for n in x], label = '$O(1)$')
plt.plot(x, [np.log(n) for n in x], label = '$O(log n)$')
plt.plot(x, [n for n in x], label = '$O(n)')
plt.plot(x, [n * (np.log(n)) for n in x], label = '$O(n log n)$')
plt.plot(x, [n ** 2 for n in x], label = '$O(n^2)$')
plt.plot(x, [2 ** n for n in x], label = '$O(2^n)$')        
plt.plot(x, [gamma(n) for n in x], label = '$O(n!)')         
plt.plot(x, [n ** n for n in x], label = '$O(n^n)')         
       

plt.ylim(top = 10, bottom = 0)
plt.xlabel('Elements')
plt.ylabel('Operations')
plt.suptitle('Big O Notation')
plt.legend()
plt.title('James Allen')


plt.show()
# Out:
# <ipython-input-47-c7600c5bc850>:7: RuntimeWarning: divide by zero encountered in log
#   plt.plot(x, [np.log(n) for n in x], label = '$O(log n)$')
# <ipython-input-47-c7600c5bc850>:9: RuntimeWarning: divide by zero encountered in log
#   plt.plot(x, [n * (np.log(n)) for n in x], label = '$O(n log n)$')
# <ipython-input-47-c7600c5bc850>:9: RuntimeWarning: invalid value encountered in double_scalars
#   plt.plot(x, [n * (np.log(n)) for n in x], label = '$O(n log n)$')
